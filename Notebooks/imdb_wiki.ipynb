# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
#bringing in imdb
imdb_df = pd.read_csv('../data/imdb_df.csv')

# %%
#bringing in wiki
wiki_df = pd.read_csv('../data/wiki_final_list.csv')

# %%
#deleting unwanted column
del imdb_df['Unnamed: 0']

# %%
#deleting unwanted column
del wiki_df['Unnamed: 0']

# %%
imdb_df
# Out:
#                                            movie_title  release_year  \
# 0                                              Titanic          1997
# 1            Star Wars: Episode I - The Phantom Menace          1999
# 2                                        The Lion King          1994
# 3                                        Jurassic Park          1993
# 4                                         Forrest Gump          1994
# ...                                                ...           ...
# 1045                                      One Good Cop          1991
# 1046                                      Chill Factor          1999
# 1047  The Adventures of Priscilla, Queen of the Desert          1994
# 1048                                               Q&A          1990
# 1049                                       Deep Rising          1998
#
#      movie_rating          director           star_one           star_two  \
# ...

# %%
imdb_df['release_year'].value_counts()
# Out:
# 1996    119
# 1999    118
# 1997    111
# 1998    111
# 1994    108
# 1995    108
# 1993    100
# 1990     93
# 1992     93
# 1991     89
# Name: release_year, dtype: int64

# %%
wiki_trim = wiki_df.rename(columns = {'Title': 'movie_title' })
wiki_trim.head(50)
# Out:
#      Opening                                   movie_title  \
# 0    JANUARY            Henry: Portrait of a Serial Killer
# 1    JANUARY                 Drug Wars: The Camarena Story
# 2    JANUARY                                      Downtown
# 3    JANUARY                              Internal Affairs
# 4    JANUARY  Leatherface: The Texas Chainsaw Massacre III
# 5    JANUARY                                    Ski Patrol
# 6    JANUARY                                    Brain Dead
# 7    JANUARY                                Everybody Wins
# 8    JANUARY                                       Tremors
# 9   FEBRUARY                                     Flashback
# 10  FEBRUARY                               Heart Condition
# 11  FEBRUARY                            A Man Called Sarge
# 12  FEBRUARY                               Men Don't Leave
# 13  FEBRUARY                                        Stella
# 14  FEBRUARY                                  Hard to Kill
# ...

# %%
#merge two dataframes 
imdb_wiki = pd.merge(imdb_df, wiki_trim, on = ['movie_title'], how='left')
imdb_wiki
# Out:
#                                            movie_title  release_year  \
# 0                                              Titanic          1997
# 1            Star Wars: Episode I - The Phantom Menace          1999
# 2                                        The Lion King          1994
# 3                                        Jurassic Park          1993
# 4                                         Forrest Gump          1994
# ...                                                ...           ...
# 1050                                      One Good Cop          1991
# 1051                                      Chill Factor          1999
# 1052  The Adventures of Priscilla, Queen of the Desert          1994
# 1053                                               Q&A          1990
# 1054                                       Deep Rising          1998
#
#      movie_rating          director           star_one           star_two  \
# ...

# %% [markdown]
# # Splitting the genre
# use iterrows
# use len3 len 2
# genre_one
# genre_two
# genre_three
# imdb_wiki[] =imdb_wiki['genre'].str.split(',', expand =True)

# %%
imdb_wiki
# Out:
#                                            movie_title  release_year  \
# 0                                              Titanic          1997
# 1            Star Wars: Episode I - The Phantom Menace          1999
# 2                                        The Lion King          1994
# 3                                        Jurassic Park          1993
# 4                                         Forrest Gump          1994
# ...                                                ...           ...
# 1050                                      One Good Cop          1991
# 1051                                      Chill Factor          1999
# 1052  The Adventures of Priscilla, Queen of the Desert          1994
# 1053                                               Q&A          1990
# 1054                                       Deep Rising          1998
#
#      movie_rating          director           star_one           star_two  \
# ...

# %%
print(len(imdb_wiki))
# Out:
# 1055

# %%
#dropping rows with na if there are more than 5
imdb_wiki['director'].value_counts()
# Out:
# Joel Schumacher        8
# Tony Scott             7
# Barry Levinson         7
# Chris Columbus         7
# Clint Eastwood         7
#                       ..
# David Mirkin           1
# Keenen Ivory Wayans    1
# John McNaughton        1
# Kinka Usher            1
# Hugh Johnson           1
# Name: director, Length: 552, dtype: int64

# %%
imdb_wiki['star_one'].value_counts()
# Out:
# Bruce Willis             15
# Mel Gibson               13
# Kevin Costner            12
# Jean-Claude Van Damme    12
# Tom Hanks                12
#                          ..
# Brian Krause              1
# Brian Bonsall             1
# Molly Shannon             1
# Mary Steenburgen          1
# Treat Williams            1
# Name: star_one, Length: 466, dtype: int64

# %%
imdb_wiki['star_two'].value_counts()
# Out:
# Meg Ryan             8
# Nicole Kidman        8
# Sharon Stone         7
# Michelle Pfeiffer    7
# Gene Hackman         7
#                     ..
# Beverly D'Angelo     1
# Carla Gugino         1
# Patrick Swayze       1
# Joaquin Phoenix      1
# Timothy Hutton       1
# Name: star_two, Length: 656, dtype: int64

# %%
imdb_wiki['star_three'].value_counts()
# Out:
# Samuel L. Jackson         5
# Joan Cusack               5
# William Sadler            4
# Gene Hackman              4
# James Remar               4
#                          ..
# Marlon Wayans             1
# Jonathan Taylor Thomas    1
# Laura Harris              1
# Brandy Norwood            1
# Anthony Heald             1
# Name: star_three, Length: 793, dtype: int64

# %%
imdb_wiki['star_four'].value_counts()
# Out:
# James Woods          5
# Oliver Platt         5
# Joan Cusack          4
# Mako                 4
# Chazz Palminteri     4
#                     ..
# Eric Lloyd           1
# Michael Rosenbaum    1
# Joss Ackland         1
# Lois Hall            1
# Kevin J. O'Connor    1
# Name: star_four, Length: 877, dtype: int64

# %%
imdb_wiki.loc[imdb_wiki.director == 'Joel Schumacher']
# Out:
#         movie_title  release_year movie_rating         director  \
# 22   Batman Forever          1995        PG-13  Joel Schumacher
# 93   A Time to Kill          1996            R  Joel Schumacher
# 97   Batman & Robin          1997        PG-13  Joel Schumacher
# 133      The Client          1994        PG-13  Joel Schumacher
# 239      Flatliners          1990            R  Joel Schumacher
# 400    Falling Down          1993            R  Joel Schumacher
# 448             8MM          1999            R  Joel Schumacher
# 485     Dying Young          1991            R  Joel Schumacher
#
#                   star_one         star_two         star_three  \
# 22              Val Kilmer  Tommy Lee Jones         Jim Carrey
# 93     Matthew McConaughey   Sandra Bullock  Samuel L. Jackson
# 97   Arnold Schwarzenegger   George Clooney    Chris O'Donnell
# 133         Susan Sarandon  Tommy Lee Jones        Brad Renfro
# 239      Kiefer Sutherland      Kevin Bacon      Julia Roberts
# ...

# %%
imdb_wiki.loc[imdb_wiki.star_one == 'Kevin Bacon']
# Out:
#            movie_title  release_year movie_rating             director  \
# 542        Wild Things          1998            R      John McNaughton
# 720     Stir of Echoes          1999            R          David Koepp
# 724   The Air Up There          1994           PG  Paul Michael Glaser
# 844            Tremors          1990        PG-13        Ron Underwood
# 1045             Balto          1995            G          Simon Wells
#
#          star_one               star_two       star_three        star_four  \
# 542   Kevin Bacon          Neve Campbell      Matt Dillon  Denise Richards
# 720   Kevin Bacon     Zachary David Cope     Kathryn Erbe  Illeana Douglas
# 724   Kevin Bacon  Charles Gitonga Maina  Yolanda Vazquez  Winston Ntshona
# 844   Kevin Bacon              Fred Ward      Finn Carter    Michael Gross
# 1045  Kevin Bacon            Bob Hoskins    Bridget Fonda     Jim Cummings
#
#       movie_length                                    genre imdb_metascore  \
# ...

# %%
imdb_wiki.loc[imdb_wiki.star_two == 'Kevin Bacon']
# Out:
#              movie_title  release_year movie_rating         director  \
# 239           Flatliners          1990            R  Joel Schumacher
# 334             Sleepers          1996            R   Barry Levinson
# 348       The River Wild          1994        PG-13    Curtis Hanson
# 819  Murder in the First          1995            R       Marc Rocco
#
#               star_one     star_two        star_three        star_four  \
# 239  Kiefer Sutherland  Kevin Bacon     Julia Roberts  William Baldwin
# 334     Robert De Niro  Kevin Bacon         Brad Pitt     Jason Patric
# 348       Meryl Streep  Kevin Bacon  David Strathairn  Joseph Mazzello
# 819   Christian Slater  Kevin Bacon       Gary Oldman   Embeth Davidtz
#
#      movie_length                                   genre imdb_metascore  \
# 239           115       Drama, Horror, Sci-Fi                         55
# 334           147      Crime, Drama, Thriller                         49
# ...

# %%
imdb_wiki.loc[imdb_wiki.star_three == 'Kevin Bacon']
# Out:
#          movie_title  release_year movie_rating            director  \
# 28         Apollo 13          1995           PG          Ron Howard
# 519  Picture Perfect          1997        PG-13  Glenn Gordon Caron
#
#              star_one     star_two   star_three        star_four  \
# 28          Tom Hanks  Bill Paxton  Kevin Bacon      Gary Sinise
# 519  Jennifer Aniston     Jay Mohr  Kevin Bacon  Olympia Dukakis
#
#      movie_length                                  genre imdb_metascore  \
# 28            140  Adventure, Drama, History                         77
# 519           101     Comedy, Drama, Romance                         44
#
#      imdb_stars imdb_votes  imdb_gross Opening  \
# 28          7.7    296,619      173.84    JUNE
# 519         5.5     20,494       31.06  AUGUST
#
#                                          Studio       Medium
# 28   Universal Pictures / Imagine Entertainment  Live action
# 519                            20th Century Fox  Live action

# %%
imdb_wiki.loc[imdb_wiki.star_four == 'Kevin Bacon']
# Out:
#        movie_title  release_year movie_rating    director    star_one  \
# 48  A Few Good Men          1992            R  Rob Reiner  Tom Cruise
#
#           star_two  star_three    star_four  movie_length  \
# 48  Jack Nicholson  Demi Moore  Kevin Bacon           138
#
#                           genre imdb_metascore  imdb_stars imdb_votes  \
# 48  Drama, Thriller                         62         7.7    265,854
#
#     imdb_gross   Opening                                         Studio  \
# 48      141.34  DECEMBER  Columbia Pictures / Castle Rock Entertainment
#
#          Medium
# 48  Live action

# %%
imdb_wiki['movie_rating'].value_counts()
# Out:
# R        493
# PG-13    315
# PG       202
# G         41
# None       2
# NC-17      2
# Name: movie_rating, dtype: int64

# %%
imdb_wiki.loc[imdb_wiki.star_one == 'Bruce Willis']
# Out:
#                    movie_title  release_year movie_rating  \
# 6              The Sixth Sense          1999        PG-13
# 19                  Armageddon          1998        PG-13
# 85                  Die Hard 2          1990            R
# 126  Die Hard with a Vengeance          1995            R
# 231          The Fifth Element          1997        PG-13
# 252         The Last Boy Scout          1991            R
# 268                 12 Monkeys          1995            R
# 269                 12 Monkeys          1995            R
# 287                 The Jackal          1997            R
# 494             Mercury Rising          1998            R
# 582            The Story of Us          1999            R
# 651          Striking Distance          1993            R
# 764             Color of Night          1994            R
# 813          Last Man Standing          1996            R
# 826                Hudson Hawk          1991            R
#
# ...

# %%
#turn this into a a seaborn bar plot. side by side columns with different color for legend 
#it looks like 1993 and 1994 had more family friendly movies and less R rated movies but R rated movies are the highest each year
# get rid of the none ratings
ratings_per_year = imdb_wiki.groupby(['release_year','movie_rating']).size().to_frame().reset_index()
#renaming column from 0 to movie_count
ratings_per_year.columns.values[2] = 'movie_count'
ratings_per_year
# Out:
#     release_year movie_rating  movie_count
# 0           1990            G            2
# 1           1990        NC-17            1
# 2           1990           PG           17
# 3           1990        PG-13           25
# 4           1990            R           49
# 5           1991            G            4
# 6           1991         None            1
# 7           1991           PG           17
# 8           1991        PG-13           22
# 9           1991            R           45
# 10          1992            G            3
# 11          1992           PG           18
# 12          1992        PG-13           26
# 13          1992            R           47
# 14          1993            G            2
# 15          1993           PG           28
# 16          1993        PG-13           30
# 17          1993            R           40
# 18          1994            G            3
# 19          1994           PG           32
# 20          1994        PG-13           34
# ...

# %%
ninety_seven = imdb_wiki.loc[imdb_wiki.release_year == 1997]

# %%
ninety_seven_dec = ninety_seven.loc[ninety_seven.Opening == 'DECEMBER']
ninety_seven_dec
# Out:
#                        movie_title  release_year movie_rating  \
# 0                          Titanic          1997        PG-13
# 42              As Good as It Gets          1997        PG-13
# 54               Good Will Hunting          1997            R
# 72             Tomorrow Never Dies          1997        PG-13
# 112                       Scream 2          1997            R
# 372                        Amistad          1997            R
# 383                    Wag the Dog          1997            R
# 409                   Jackie Brown          1997            R
# 513           For Richer or Poorer          1997        PG-13
# 522                   Home Alone 3          1997           PG
# 589  An American Werewolf in Paris          1997            R
# 713                      Mr. Magoo          1997           PG
# 733                    The Apostle          1997        PG-13
# 812                    The Postman          1997            R
#
# ...

# %% [markdown]
# ### finding the top 10 grossing movies in each year

# %%
imdb_90 = imdb_wiki.loc[imdb_wiki.release_year == 1990].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_90
# Out:
#                       movie_title  release_year movie_rating        director  \
# 7                      Home Alone          1990           PG  Chris Columbus
# 14                          Ghost          1990        PG-13    Jerry Zucker
# 21             Dances with Wolves          1990        PG-13   Kevin Costner
# 26                   Pretty Woman          1990            R  Garry Marshall
# 59   Teenage Mutant Ninja Turtles          1990           PG    Steve Barron
# 76       The Hunt for Red October          1990           PG  John McTiernan
# 83                   Total Recall          1990            R  Paul Verhoeven
# 85                     Die Hard 2          1990            R    Renny Harlin
# 105                    Dick Tracy          1990           PG   Warren Beatty
# 135              Kindergarten Cop          1990        PG-13    Ivan Reitman
#
#                   star_one             star_two        star_three  \
# ...

# %%
imdb_91 = imdb_wiki.loc[imdb_wiki.release_year == 1991].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_91
# Out:
#                              movie_title  release_year movie_rating  \
# 13                  Beauty and the Beast          1991            G
# 18            Terminator 2: Judgment Day          1991            R
# 33         Robin Hood: Prince of Thieves          1991        PG-13
# 62              The Silence of the Lambs          1991            R
# 74                         City Slickers          1991        PG-13
# 82                                  Hook          1991           PG
# 90                     The Addams Family          1991        PG-13
# 111              Sleeping with the Enemy          1991            R
# 141                  Father of the Bride          1991           PG
# 146  The Naked Gun 2½: The Smell of Fear          1991        PG-13
#
#              director               star_one           star_two  \
# 13     Gary Trousdale              Kirk Wise       Paige O'Hara
# 18      James Cameron  Arnold Schwarzenegger     Linda Hamilton
# ...

# %%
imdb_92 = imdb_wiki.loc[imdb_wiki.release_year == 1992].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_92
# Out:
#                        movie_title  release_year movie_rating  \
# 15                         Aladdin          1992            G
# 29  Home Alone 2: Lost in New York          1992           PG
# 35                  Batman Returns          1992        PG-13
# 45                 Lethal Weapon 3          1992            R
# 48                  A Few Good Men          1992            R
# 53                      Sister Act          1992           PG
# 77                   The Bodyguard          1992            R
# 78                   Wayne's World          1992        PG-13
# 84                  Basic Instinct          1992            R
# 96           A League of Their Own          1992           PG
#
#              director         star_one         star_two         star_three  \
# 15       Ron Clements      John Musker    Scott Weinger     Robin Williams
# 29     Chris Columbus  Macaulay Culkin        Joe Pesci       Daniel Stern
# ...

# %%
imdb_93 = imdb_wiki.loc[imdb_wiki.release_year == 1993].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_93
# Out:
#               movie_title  release_year movie_rating           director  \
# 3           Jurassic Park          1993        PG-13   Steven Spielberg
# 12         Mrs. Doubtfire          1993        PG-13     Chris Columbus
# 23           The Fugitive          1993        PG-13       Andrew Davis
# 38               The Firm          1993            R     Sydney Pollack
# 70   Sleepless in Seattle          1993           PG        Nora Ephron
# 99      Indecent Proposal          1993            R        Adrian Lyne
# 109   In the Line of Fire          1993            R  Wolfgang Petersen
# 119     The Pelican Brief          1993        PG-13     Alan J. Pakula
# 129      Schindler's List          1993            R   Steven Spielberg
# 150           Cliffhanger          1993            R       Renny Harlin
#
#                star_one            star_two       star_three  \
# 3             Sam Neill          Laura Dern    Jeff Goldblum
# ...

# %%
imdb_94 = imdb_wiki.loc[imdb_wiki.release_year == 1994].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_94
# Out:
#                  movie_title  release_year movie_rating           director  \
# 2              The Lion King          1994            G       Roger Allers
# 4               Forrest Gump          1994        PG-13    Robert Zemeckis
# 43                 True Lies          1994            R      James Cameron
# 44          The Santa Clause          1994           PG       John Pasquin
# 63           The Flintstones          1994           PG       Brian Levant
# 67           Dumb and Dumber          1994        PG-13     Peter Farrelly
# 75  Clear and Present Danger          1994        PG-13      Phillip Noyce
# 79                     Speed          1994            R        Jan de Bont
# 81                  The Mask          1994        PG-13      Chuck Russell
# 95              Pulp Fiction          1994            R  Quentin Tarantino
#
#                  star_one           star_two         star_three  \
# 2             Rob Minkoff  Matthew Broderick       Jeremy Irons
# ...

# %%
imdb_95 = imdb_wiki.loc[imdb_wiki.release_year == 1995].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_95
# Out:
#                         movie_title  release_year movie_rating  \
# 20                        Toy Story          1995            G
# 22                   Batman Forever          1995        PG-13
# 28                        Apollo 13          1995           PG
# 47                       Pocahontas          1995            G
# 94   Ace Ventura: When Nature Calls          1995        PG-13
# 100                       GoldenEye          1995        PG-13
# 121                         Jumanji          1995           PG
# 122                          Casper          1995           PG
# 125                           Se7en          1995            R
# 126       Die Hard with a Vengeance          1995            R
#
#             director        star_one         star_two         star_three  \
# 20     John Lasseter       Tom Hanks        Tim Allen        Don Rickles
# 22   Joel Schumacher      Val Kilmer  Tommy Lee Jones         Jim Carrey
# ...

# %%
imdb_96 = imdb_wiki.loc[imdb_wiki.release_year == 1996].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_96
# Out:
#             movie_title  release_year movie_rating         director  \
# 5      Independence Day          1996        PG-13  Roland Emmerich
# 10              Twister          1996        PG-13      Jan de Bont
# 25  Mission: Impossible          1996        PG-13   Brian De Palma
# 40        Jerry Maguire          1996            R    Cameron Crowe
# 56               Ransom          1996            R       Ron Howard
# 58       101 Dalmatians          1996            G    Stephen Herek
# 61             The Rock          1996            R      Michael Bay
# 66  The Nutty Professor          1996        PG-13      Tom Shadyac
# 73         The Birdcage          1996            R     Mike Nichols
# 93       A Time to Kill          1996            R  Joel Schumacher
#
#                star_one            star_two         star_three  \
# 5            Will Smith        Bill Pullman      Jeff Goldblum
# 10           Helen Hunt         Bill Paxton         Cary Elwes
# ...

# %%
imdb_97 = imdb_wiki.loc[imdb_wiki.release_year == 1997].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_97
# Out:
#                       movie_title  release_year movie_rating  \
# 0                         Titanic          1997        PG-13
# 8                    Men in Black          1997        PG-13
# 11  The Lost World: Jurassic Park          1997        PG-13
# 24                      Liar Liar          1997        PG-13
# 30                  Air Force One          1997            R
# 42             As Good as It Gets          1997        PG-13
# 54              Good Will Hunting          1997            R
# 68       My Best Friend's Wedding          1997        PG-13
# 72            Tomorrow Never Dies          1997        PG-13
# 91                       Face/Off          1997            R
#
#               director           star_one         star_two  \
# 0        James Cameron  Leonardo DiCaprio     Kate Winslet
# 8     Barry Sonnenfeld    Tommy Lee Jones       Will Smith
# 11    Steven Spielberg      Jeff Goldblum   Julianne Moore
# ...

# %%
imdb_98 = imdb_wiki.loc[imdb_wiki.release_year == 1998].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_98
# Out:
#                      movie_title  release_year movie_rating          director  \
# 16           Saving Private Ryan          1998            R  Steven Spielberg
# 19                    Armageddon          1998        PG-13       Michael Bay
# 27  There's Something About Mary          1998            R    Bobby Farrelly
# 36                  A Bug's Life          1998            G     John Lasseter
# 37                  The Waterboy          1998        PG-13      Frank Coraci
# 46               Doctor Dolittle          1998        PG-13      Betty Thomas
# 49                     Rush Hour          1998        PG-13      Brett Ratner
# 51                   Deep Impact          1998        PG-13        Mimi Leder
# 57                      Godzilla          1998        PG-13   Roland Emmerich
# 60                   Patch Adams          1998        PG-13       Tom Shadyac
#
#              star_one            star_two     star_three  \
# ...

# %%
imdb_99 = imdb_wiki.loc[imdb_wiki.release_year == 1999].sort_values(by=['imdb_gross'],ascending=False).head(10)
imdb_99
# Out:
#                                   movie_title  release_year movie_rating  \
# 1   Star Wars: Episode I - The Phantom Menace          1999           PG
# 6                             The Sixth Sense          1999        PG-13
# 9                                 Toy Story 2          1999            G
# 17      Austin Powers: The Spy Who Shagged Me          1999        PG-13
# 31                                 The Matrix          1999            R
# 32                                     Tarzan          1999            G
# 34                                  Big Daddy          1999        PG-13
# 39                                  The Mummy          1999        PG-13
# 41                              Runaway Bride          1999           PG
# 50                    The Blair Witch Project          1999            R
#
#               director         star_one           star_two  \
# 1         George Lucas    Ewan McGregor        Liam Neeson
# ...

# %%
imdb_wiki.sort_values(by = ['release_year', 'imdb_gross'], axis=0, ascending=[True, False], inplace=False,
               kind='quicksort', na_position='first', ignore_index=True, key=None)
# Out:
#                                movie_title  release_year movie_rating  \
# 0                               Home Alone          1990           PG
# 1                                    Ghost          1990        PG-13
# 2                       Dances with Wolves          1990        PG-13
# 3                             Pretty Woman          1990            R
# 4             Teenage Mutant Ninja Turtles          1990           PG
# ...                                    ...           ...          ...
# 1050  The Adventures of Elmo in Grouchland          1999            G
# 1051                              The Muse          1999        PG-13
# 1052                        Wing Commander          1999        PG-13
# 1053                        Boys Don't Cry          1999            R
# 1054                          Chill Factor          1999            R
#
#              director            star_one         star_two        star_three  \
# ...

# %%
# concating the dfs so I have one that has all top ten grossing movies for each year making 100 movies
top_gross_movies= pd.concat([imdb_90,imdb_91,imdb_92,imdb_93,imdb_94,imdb_95,imdb_96,imdb_97,imdb_98,imdb_99], axis=0).reset_index()
top_gross_movies
# Out:
#     index                   movie_title  release_year movie_rating  \
# 0       7                    Home Alone          1990           PG
# 1      14                         Ghost          1990        PG-13
# 2      21            Dances with Wolves          1990        PG-13
# 3      26                  Pretty Woman          1990            R
# 4      59  Teenage Mutant Ninja Turtles          1990           PG
# ..    ...                           ...           ...          ...
# 95     32                        Tarzan          1999            G
# 96     34                     Big Daddy          1999        PG-13
# 97     39                     The Mummy          1999        PG-13
# 98     41                 Runaway Bride          1999           PG
# 99     50       The Blair Witch Project          1999            R
#
#            director         star_one           star_two           star_three  \
# 0    Chris Columbus  Macaulay Culkin          Joe Pesci         Daniel Stern
# ...

# %%
title_year = top_gross_movies[['movie_title','release_year']]

# %%
title_year.to_csv('title_year.csv')

# %%
#making a list of the 100 movies so that i can pull it from rotten tomato
top_gross_movies.to_csv('top_gross_movies.csv')

# %%
top_twenty = top_gross_movies.sort_values(by = ('imdb_gross'), ascending=False).head(20)

# %%
top_twenty_list = top_twenty.movie_title.to_list()

# %%
#only keeping the first genre listed
top_gross_movies.genre= top_gross_movies.genre.str.split(',', expand = True)[0]

# %%
#only keeping the main production company
top_gross_movies.Studio = top_gross_movies.Studio.str.split(' /', expand = True)[0]

# %%
top_gross_movies.head(5)
# Out:
#    index                   movie_title  release_year movie_rating  \
# 0      7                    Home Alone          1990           PG
# 1     14                         Ghost          1990        PG-13
# 2     21            Dances with Wolves          1990        PG-13
# 3     26                  Pretty Woman          1990            R
# 4     59  Teenage Mutant Ninja Turtles          1990           PG
#
#          director         star_one        star_two       star_three  \
# 0  Chris Columbus  Macaulay Culkin       Joe Pesci     Daniel Stern
# 1    Jerry Zucker   Patrick Swayze      Demi Moore  Whoopi Goldberg
# 2   Kevin Costner    Kevin Costner  Mary McDonnell    Graham Greene
# 3  Garry Marshall     Richard Gere   Julia Roberts  Jason Alexander
# 4    Steve Barron      Judith Hoag    Elias Koteas        Josh Pais
#
#            star_four  movie_length      genre imdb_metascore  imdb_stars  \
# 0         John Heard           103     Comedy             63         7.7
# ...

# %%
tomato = pd.read_csv('../data/tomato_score_final.csv')

# %%
#deleting the column i don't need
del tomato['Unnamed: 0']

# %%
#trimming the df so that the random numbers at the bottom are gone
tomato_trim = tomato.drop(tomato.index[[100,101,102,103,104,105,106,107,108,109]], axis = 0)

# %%
imdb_tomato = pd.merge(top_gross_movies,tomato_trim, on = "movie_title", how = "inner")
#deleting index column that is not needed
del imdb_tomato['index']
imdb_tomato
# Out:
#                      movie_title  release_year movie_rating         director  \
# 0                     Home Alone          1990           PG   Chris Columbus
# 1                          Ghost          1990        PG-13     Jerry Zucker
# 2             Dances with Wolves          1990        PG-13    Kevin Costner
# 3                   Pretty Woman          1990            R   Garry Marshall
# 4   Teenage Mutant Ninja Turtles          1990           PG     Steve Barron
# ..                           ...           ...          ...              ...
# 95                        Tarzan          1999            G       Chris Buck
# 96                     Big Daddy          1999        PG-13     Dennis Dugan
# 97                     The Mummy          1999        PG-13  Stephen Sommers
# 98                 Runaway Bride          1999           PG   Garry Marshall
# 99       The Blair Witch Project          1999            R    Daniel Myrick
#
# ...

# %%
imdb_tomato.to_csv('imdb_tomato_final.csv')
