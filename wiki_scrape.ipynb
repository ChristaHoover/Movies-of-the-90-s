# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs

# %%
#bring in url
url = 'https://en.wikipedia.org/wiki/1990s_in_film'
wiki_tables =
response = requests.get(url)

# %%
#making soup
soup = bs(response.content, 'lxml')

# %%
wiki_info = soup.find('div', attrs = {'class' : 'wikitable sortable'})

# %%
for x in wiki_info:
    title = x.td.i

# %%
wiki_info

# %%
table_html = str(soup.find('table', attrs={'class' : 'wikitable sortable'}))

from IPython.core.display import HTML

HTML(table_html)
# Out:
# <table class="wikitable sortable" style="margin:auto; margin:auto;">
# <caption>List of worldwide highest-grossing films
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Title
# </th>
# <th>Studios
# </th>
# <th>Worldwide gross
# </th>
# <th>Year
# </th>
# <th>Ref.
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><i><a href="/wiki/Titanic_(1997_film)" title="Titanic (1997 film)">Titanic</a></i>
# </td>
# <td><a href="/wiki/Paramount_Pictures" title="Paramount Pictures">Paramount Pictures</a>/<a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
# </td>
# <td>$1,843,201,268
# </td>
# <td><a href="/wiki/1997_in_film" title="1997 in film">1997</a>
# </td>
# <td><div style="text-align: center;"><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[# 1]</a></sup></div>
# </td></tr>
# <tr>
# <td>2
# </td>
# ...

# %%
imdb_list_df.to_csv('imdb_movie_df.csv')

# %%
type(pd.read_html(str(soup.find('table', attrs={'class' : 'wikitable'})))[0])
